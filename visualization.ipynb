# %%
import os
import pandas as pd 
from glob import glob

# %%
os.chdir("C:\\Users\\pratiksha\\Downloads\\Data")

# %%
extention='csv'

# %%
all_filenames=[i for i in glob('*.{}'.format(extention))]

# %%
Combined_csv=pd.concat([pd.read_csv(f) for f in all_filenames])
Combined_csv
# Out:
#     Unnamed: 0                            Content ID Content Type  \
# 0            0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo
# 1            1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo
# 2            2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo
# 3            3  356fff80-da4d-4785-9f43-bc1261031dc6        photo
# 4            4  01ab84dd-6364-4236-abbb-3f237db77180        video
# ..         ...                                   ...          ...
# 11          11                                   NaN          NaN
# 12          12                                   NaN          NaN
# 13          13                                   NaN          NaN
# 14          14                                   NaN          NaN
# 15          15                                   NaN          NaN
#
#           Category  Unnamed: 4       Type Datetime Sentiment  Score
# 0         Studying         NaN        NaN      NaN       NaN    NaN
# ...

# %%
Combined_csv.to_csv("C:\\Users\\pratiksha\\Downloads\\Final _df.csv", index=False,encoding="utf-8")

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\pratiksha\\Downloads\\Task 3_Final Content Data set.csv")
df
# Out:
#        Unnamed: 0                            Content ID Reaction Type  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...           ...                                   ...           ...
# 24568       24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569       24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570       24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571       24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572       24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#             Datetime Content Type    Category Sentiment  Score
# 0       7/11/20 9:43        photo    studying  negative      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24573 entries, 0 to 24572
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     24573 non-null  int64
#  1   Content ID     24573 non-null  object
#  2   Reaction Type  24573 non-null  object
#  3   Datetime       24573 non-null  object
#  4   Content Type   24573 non-null  object
#  5   Category       24573 non-null  object
#  6   Sentiment      24573 non-null  object
#  7   Score          24573 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 1.5+ MB

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Content ID       object
# Reaction Type    object
# Datetime         object
# Content Type     object
# Category         object
# Sentiment        object
# Score             int64
# dtype: object

# %%
df.shape
# Out:
# (24573, 8)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Content ID', 'Reaction Type', 'Datetime', 'Content Type',
#        'Category', 'Sentiment', 'Score'],
#       dtype='object')

# %%
df1 = df.rename({'Unnamed: 0': 'na','Content ID': 'Content_ID','Reaction Type': 'Reaction_Type','Content Type': 'Content_Type'}, axis=1)

# %%
df1
# Out:
#           na                            Content_ID Reaction_Type  \
# 0          0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1          1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2          2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3          3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4          4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...      ...                                   ...           ...
# 24568  24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569  24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570  24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571  24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572  24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#             Datetime Content_Type    Category Sentiment  Score
# 0       7/11/20 9:43        photo    studying  negative      0
# ...

# %%
df2=df1.drop('na',axis=1)
df2
# Out:
#                                  Content_ID Reaction_Type       Datetime  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust   7/11/20 9:43
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  17/6/21 12:22
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared   18/4/21 5:13
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust   6/1/21 19:13
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  23/8/20 12:25
# ...                                     ...           ...            ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike   27/6/20 9:46
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued  16/2/21 17:17
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested   12/9/20 3:54
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried  4/11/20 20:08
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish    4/1/21 4:55
#
#       Content_Type    Category Sentiment  Score
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2['Category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
top_categories = df2['Content_Type'].value_counts().head(5)

plt.figure(figsize=(10, 6))
top_categories.plot(kind='barh', color='skyblue')
plt.title('Top 5 Content Categories')
plt.xlabel('Aggrigate "Popularity"Score')
plt.ylabel('Category')
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['Category'].value_counts().head(5).plot.pie(autopct='%1.1f%%', startangle=90, cmap='Paired')
plt.title('Top 5 Content Categories')
plt.ylabel('')
plt.show()

# %%
unique_categories_count = df2['Category'].nunique()
print(f"There are {unique_categories_count} unique categories.")
# Out:
# There are 16 unique categories.

# %%
most_popular_category = df2['Category'].value_counts().idxmax()

most_popular_category
# Out:
# 'animals'

# %%
import matplotlib.pyplot as plt

import pandas as pd

# Assuming df is your DataFrame
# Replace 'Category', 'Reactions', and 'Date' with the actual column names in your DataFrame
pivot_table = pd.pivot_table(df2, index='Category', columns='Datetime', aggfunc='sum', fill_value=0)

# Display the pivot table
print(pivot_table)
# Out:
# C:\Users\pratiksha\AppData\Local\Temp\ipykernel_7960\1452079803.py:7: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pivot_table = pd.pivot_table(df2, index='Category', columns='Datetime', aggfunc='sum', fill_value=0)
#                       Score                                        \
# Datetime        1/1/21 0:28 1/1/21 0:41 1/1/21 10:24 1/1/21 11:23
# Category
# animals                   0           0            0            0
# cooking                   0           0            0            0
# culture                   0           0            0            0
# dogs                      0           0            0            0
# education                 0           0            0            0
# fitness                   0           0           10            0
# ...
